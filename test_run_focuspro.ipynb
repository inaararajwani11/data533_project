# %%
pip install focuspro-data533==0.0.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
from project import run_demo
sys.argv = ["focuspro-demo"]  # add flags here if needed
run_demo.main()
# Out:
# === Focus Pro Demo ===
# Before we start, we'll review previous tasks and optionally remove finished ones.
#
# Do you want to add tasks now? (y/N): y
# Enter tasks
# How many tasks do you want to add? (0 to skip): 2
#
# Task 1 of 2
# Task name: revision
# Duration minutes (default 25): 20
# Categories:
#   1. study
#   2. admin
#   3. recovery
#   4. personal
#   5. health
#   6. work
# Pick category number or type custom (Enter to skip): 1
# Difficulty 1-5 (default 3): 1
# Priority (default 1): 1
# Use Pomodoro (25/5)? (y/N): n
# Added task.
#
#
# Task 2 of 2
# Task name: exercise
# Duration minutes (default 25): 40
# Categories:
#   1. study
#   2. admin
#   3. recovery
#   4. personal
#   5. health
#   6. work
# Pick category number or type custom (Enter to skip): 5
# Difficulty 1-5 (default 3): 1
# Priority (default 1): 3
# Added task.
#
# Review previous tasks before planning? (y/N): y
#
# Existing tasks:
#   1. revision (20 min, cat=study)
#   2. exercise (40 min, cat=health)
# ...

# %%
#file.txt will be written to the notebook’s working directory.
import sys
from project import run_demo
sys.argv = ["run_demo", "--export", "file.txt"]  # add --auto if desired
run_demo.main()
# Out:
# === Focus Pro Demo ===
# Before we start, we'll review previous tasks and optionally remove finished ones.
#
# Do you want to add tasks now? (y/N): y
# Enter tasks
# How many tasks do you want to add? (0 to skip): 2
#
# Task 1 of 2
# Task name: revision
# Duration minutes (default 25): 30
# Categories:
#   1. study
#   2. admin
#   3. recovery
#   4. personal
#   5. health
#   6. work
# Pick category number or type custom (Enter to skip): 1
# Difficulty 1-5 (default 3): 1
# Priority (default 1): 1
# Use Pomodoro (25/5)? (y/N): y
# Added task.
#
#
# Task 2 of 2
# Task name: family updates
# Duration minutes (default 25): 10
# Categories:
#   1. study
#   2. admin
#   3. recovery
#   4. personal
#   5. health
#   6. work
# Pick category number or type custom (Enter to skip): 4
# Difficulty 1-5 (default 3):
# Priority (default 1):
# Added task.
#
# Review previous tasks before planning? (y/N): y
#
# Existing tasks:
#   1. revision (30 min, cat=study)
# ...
